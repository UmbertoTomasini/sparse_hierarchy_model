# %%
import torch
from torch.utils.data import Dataset
import torch.nn.functional as F
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import itertools 
import random
import numpy as np
import matplotlib.lines as mlines
import pickle
import io

class CPU_Unpickler(pickle.Unpickler):
    def find_class(self, module, name):
        if module == 'torch.storage' and name == '_load_from_bytes':
            return lambda b: torch.load(io.BytesIO(b), map_location='cpu')
        else:
            return super().find_class(module, name)
def load_file(f):
    with open(f, "rb") as rb:
        pickle.load(rb)
        #return pickle.load(rb)
        return CPU_Unpickler(rb).load()

# %%
def choice_lr(net,s,s0,L):
    if net =='lcn' or net=='lcn_shared':
        if s>2:
            lr = .003
        else:
            if s0<4:
                lr = 0.01
            else:
                lr = 0.003
    elif net=="cnn2":
        if s>2:
            if s0<4:
                lr = 0.01
            elif s0==4:
                lr = 0.003
            elif s0==6:
                lr = 0.0003

        else:
            if s0>0:
                if L>=3:
                    if s0<4:
                        lr = 0.01
                    elif s0==4:
                        lr = 0.003
                    else:
                        lr = 0.001
                elif L==2:
                    if s0<4:
                        lr = 0.1
                    elif s0==4:
                        lr = 0.03
                    else:
                        lr = 0.01
            else:
                lr = 0.01
            if L==1:
                if s0<4:
                    lr = 0.1
                else:
                    lr = .03
    return lr

def training_point(net,s,s0,L,n,m):
    if net=='lcn' or net=='lcn_shared':
        if s==2:
            p_pred = n**(L)
            #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)


            if s0 <4:
                xx= np.logspace(np.log10(int(p_pred)),np.log10(200*p_pred),15)
                xx =xx[:-1]
            else:
                xx= np.logspace(np.log10(p_pred),np.log10(500*p_pred),15)
                xx =xx[:-1]
                #xx1 = np.array([107999,135917])
                #xx = np.concatenate((xx,xx1))
        if s>2:
            p_pred = ((s0+1)**L)*m**(L)
            
            xx= np.logspace(np.log10(int(0.1*p_pred)),np.log10(10*p_pred),10)
            xx1 = np.logspace(np.log10(10*p_pred),np.log10(100*p_pred),10)
            xx = np.concatenate((xx,xx1))
    else:
        if s>2: 
            p_pred = n**(L)
            #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)


            if s0 <=4:
                xx= np.logspace(np.log10(int(p_pred)),np.log10(100*p_pred),15)
                xx =xx[:-1]
            else:
                xx= np.logspace(np.log10(p_pred),np.log10(500*p_pred),15)
                xx =xx[:-1]
                #xx1 = np.array([107999,135917])
                #xx = np.concatenate((xx,xx1))

            if s==3 or s==4:
                if L==2:
                    xx1= np.logspace(np.log10(100*p_pred),np.log10(500*p_pred),15)
                    xx = np.concatenate((xx,xx1))
                    xx1= np.logspace(np.log10(500*p_pred),np.log10(1000*p_pred),15)
                    xx = np.concatenate((xx,xx1))
                if s==4:
                    xx1= np.logspace(np.log10(1000*p_pred),np.log10(2000*p_pred),10)                            
                    xx = np.concatenate((xx,xx1))
                    xx1= np.logspace(np.log10(2000*p_pred),np.log10(10000*p_pred),10)                            
                    xx = np.concatenate((xx,xx1))
                    xx1= np.logspace(np.log10(10000*p_pred),np.log10(50000*p_pred),10)                            
                    xx = np.concatenate((xx,xx1))
                if s==3 and s0==4:
                    xx1= np.logspace(np.log10(int(1000*p_pred)),np.log10(10000*p_pred),10)
                    xx = np.concatenate((xx,xx1))
        else:
            p_pred = n**(L+1)
            #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
            if L>1:
                if s0>0:
                    if L>=3:
                        pmax = 110000

                        if s0 <4:
                            xx= np.logspace(np.log10(p_pred),np.log10(100*p_pred),15)

                        else:
                            xx= np.logspace(np.log10(p_pred),np.log10(300*p_pred),15)
                        if s0==1:
                            if n==8 or n==10:
                                xx0 = np.logspace(np.log10(int(0.1*p_pred)),np.log10(p_pred),5)
                                xx0 = xx0[:-1]
                                xx = np.concatenate((xx0,xx))
                    elif L==2:
                        pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
                        p_pred = n**(L+1)
                        p_max_used = min(pmax,110000)
                        #p_pred = n**(L+1)
                        if s0>=4:
                            xx= np.logspace(np.log10(p_pred),np.log10(p_max_used),15)
                        else:
                            xx= np.logspace(np.log10(p_pred),np.log10(pmax),15)

                else:
                    p_pred_red = n**L
                    xx= np.logspace(np.log10(int(0.2*p_pred_red)),np.log10(100*p_pred_red),15)
            else:
                p_pred_1 = n**L
                if s0 <4:
                    xx= np.logspace(np.log10(p_pred_1),np.log10(200*p_pred_1),15)

                else:
                    xx= np.logspace(np.log10(p_pred_1),np.log10(500*p_pred_1),15)
            if s==3:
                p_pred = (s0+1)*m**(L)
                #p_max_used = min(pmax,110000)
                #p_pred = n**(L+1)
                if s0 <= 4:
                    #xx1= np.logspace(np.log10(int(1000*p_pred)),np.log10(2000*p_pred),10)
                    #xx = np.concatenate((xx,xx1))
                    xx= np.logspace(np.log10(int(0.1*p_pred)),np.log10(10*p_pred),15)
            xx =xx[:-1]
    return xx

def load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr):
    if net=='lcn_shared':
        #print("lcn_shared_new/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_q_"+str(q)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        tmp = load_file("lcn_shared_new/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_q_"+str(q)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        
    if net=='lcn':
        if s>2:
            #net+"_data_L"+str(2)+"_A_0s
            tmp = load_file("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
            #if L>3:
            #    tmp = load_file(net+"_data_L"+str(3)+"_A_0s/hier1_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        else:
            if L==1:
                #print(ptr)
                tmp = load_file("lcn_L1/hier1_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(2)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")

            else:
                #if L<=3:
                tmp = load_file(net+"_data_L"+str(2)+"_A_0s/hier1_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    elif net=='cnn2':                       
        if s>2:
            if ptr>= 176055 and s==4:
                lr_tmp = 0.005
                tmp = load_file("cnn_s_max/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr_tmp)+".npy")
            else:
                tmp = load_file("cnn_s_max/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        else:
            if L==1:
            #print(ptr)
                tmp = load_file("cnn_L1/hier1_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")

            else:
                if s0==0:
                    tmp = load_file("check_s0/hier1_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")

                else:
                    if L<=3:
                        tmp = load_file(net+"_data_L"+str(L)+"_A_0s/hier1_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
                    if L>3:
                        tmp = load_file(net+"_data_L"+str(3)+"_A_0s/hier1_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    return tmp


def training_point_new(xx,net,n,m,L,q,s0,s,width,lr):
    xx_new = []
                
    for ptrx in xx:

        #print(ptrx,pmax)
        ptr = int(ptrx) 


        tmp_seed = 0

        num_seeds = 0
        for (idx_seed,seed) in enumerate(np.array([1])):

            try:

                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                tmp_seed += (100-tmp[choice]["acc"])/100
                num_seeds +=1
                xx_new.append(ptr)
            except:
                #if s>2:
                #    print("cnn_s_max/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
                #print('s0 not happened: '+str(s0)+'and P: '+str(ptr))
                pass
    xx_new = torch.tensor(xx_new)
    return xx_new

# %%
n = 8
sss= [2]

###### L=3 ########
#NO WHITENING
choice = "best"

#lr = .1
width = 512
seed = 0
nets =["lcn_shared"]#i

fig, axs = plt.subplots(1,2, figsize = (9,4))
s0s = [1,2,4] #,2,4,6
Ls=[2]

for (idxL,L) in enumerate(Ls):
    colors = cm.rainbow(np.linspace(0, 1, L+1))
    if L==2: lss = '-'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
        
    for (idxq,q) in enumerate(range(L+1)):
        col = 'C'+str(idxq)#colors[idxq]
        #col = colors[idxq]
        
        
    
        for (idx_s0,s0) in enumerate(s0s):
            print(s0)
    
            
            
            for (idxs,s) in enumerate(sss):
    
                if s==4 and s0>0:
                    break
                
                
                m = n**(s-1)
                for (idxnet,net) in enumerate(nets):
                    axs[0].set_title(" Net: "+net)
                    #print(n)
                    lr = choice_lr(net,s,s0,L)
    
                    accs_cnn = []
                    
                    xx = training_point(net,s,s0,L,n,m)
                    xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
                    
                    for ptrx in xx:
    
                        #print(ptrx,pmax)
                        ptr = int(ptrx) 
                        
                        
                        tmp_seed = 0
    
                        num_seeds = 0
                        for (idx_seed,seed) in enumerate(np.array([1])):
    
    
                        #print(ptr)
                            try:
                                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                tmp_seed += (100-tmp[choice]["acc"])/100
                                num_seeds +=1
                            except:
                                #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    
                                pass
                        if num_seeds>0:
                            accs_cnn.append(tmp_seed/num_seeds)
                    if idx_s0==0: 
                        axs[0].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col,label =r"$q=%d$"%q)  
                    else:
                        axs[0].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col) 
                    if s0==1:
                        mar = "o"
                    elif s0==2:
                        mar = "x"
                    elif s0==4:
                        mar = "s"
                    elif s0==6:
                        mar = "v"
                    elif s0==0:
                        mar = "d"
                    axs[0].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
    
                    #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                    #plt.axvline(x=n**4,color="red")
                    #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                    axs[0].set_xlabel(r"$P$",size = 15)
                    axs[0].set_ylabel("Test error",size = 15)
                    axs[0].set_xscale("log")
#axs[0].set_yscale("log")
#legend symbols s0
s01 = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
              markersize=7, label=r'$s_0=1$')
s02 = mlines.Line2D([], [], color='black', marker='x', linestyle='None',
              markersize=7, label=r'$s_0=2$')
s03 = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
              markersize=7, label=r'$s_0=4$')
s04 = mlines.Line2D([], [], color='black', marker='v', linestyle='None',
              markersize=7, label=r'$s_0=6$')
s00 = mlines.Line2D([], [], color='black', marker='d', linestyle='None',
              markersize=7, label=r'$s_0=0$')
first_legend = axs[0].legend()
ax = axs[0].add_artist(first_legend)
legend1 = axs[0].legend(handles=[s01,s02,s03],loc = 'upper left')   
axs[0].add_artist(legend1)

#legend linestyles -- vs - for L
'''
s01 = mlines.Line2D([], [], color='black', marker=None, linestyle='--',
              markersize=7, label=r'$L=2$')
s02 = mlines.Line2D([], [], color='black', marker=None, linestyle='-',
              markersize=7, label=r'$L=3$')
s03 = mlines.Line2D([], [], color='black', marker=None, linestyle=':',
              markersize=7, label=r'$L=1$')
#second_legend = axs[0].legend()
#ax = axs[0].add_artist(second_legend)
legend2 = axs[0].legend(handles=[s03,s01,s02],loc = 'upper right')   
axs[0].add_artist(legend2)
#legend colors n
'''
'''
list = []
for (idxs,s) in enumerate(sss):
    nlist.append(mlines.Line2D([], [], color=colors[idxs], marker=None, linestyle='-',
              markersize=7, label=r'$s=%d$'%(s)))
#third_legend = axs[0].legend()
#ax = axs[0].add_artist(third_legend)
axs[0].legend(handles=nlist,loc = 'lower left')  
'''
  
###############################################################



###### L=3 ########
#NO WHITENING

nets =["lcn_shared"]#


for (idxL,L) in enumerate(Ls):
    colors = cm.rainbow(np.linspace(0, 1, L+1))
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
        
    for (idxq,q) in enumerate(range(L+1)):
        
        col = 'C'+str(idxq)#colors[idxq]
        for (idx_s0,s0) in enumerate(s0s):
            print(s0)
    
            
            for (idxs,s) in enumerate(sss):

                m = n**(s-1)
                for (idxnet,net) in enumerate(nets):
                    axs[0].set_title("LCN shared")
                    #print(n)
                    lr = choice_lr(net,s,s0,L)
    
                    accs_cnn = []
                    
                    #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
    
    
                    xx = training_point(net,s,s0,L,n,m)
                    xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)

                    for ptrx in xx:
    
                        #print(ptrx,pmax)
                        ptr = int(ptrx) 
                        
                        
                        tmp_seed = 0
    
                        num_seeds = 0
                        for (idx_seed,seed) in enumerate(np.array([1])):
    
    
                        #print(ptr)
                            try:
                                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                tmp_seed += (100-tmp[choice]["acc"])/100
                                num_seeds +=1
                            except:
                                #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    
                                pass
                        if num_seeds>0:
                            accs_cnn.append(tmp_seed/num_seeds)
                     
                    if idxnet==0:
    
                        fac_m = 1#n*m**(L)
                        xx = xx/((s0+1)**(L-q))
    
                        axs[idxnet+1].set_xlabel(r"$P/(s_0+1)^{L-q}$",size = 15)
                    elif idxnet==1:
                        fac_m = n*m**(L)
                        xx = xx/(fac_m*(s0+1)**(L))
    
                        axs[idxnet+1].set_xlabel(r"$P/(s_0+1)^L$",size = 15)
                    elif idxnet==2:
                        fac_m = n*m**(L)
                        
                        xx = xx/(fac_m*(s0+1)**(L-1+s))
    
                        axs[idxnet+1].set_xlabel(r"$P/[(s_0+1)^{L-1}(s_0+1)^s]$",size = 15)
    
                    axs[idxnet+1].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                    
                    if s0==1:
                        mar = "o"
                    elif s0==2:
                        mar = "x"
                    elif s0==4:
                        mar = "s"
                    elif s0==6:
                        mar = "v"
                    elif s0==0:
                        mar = "d"
                    axs[idxnet+1].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
    
                    #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                    #plt.axvline(x=n**4,color="red")
                    #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                    
                    axs[idxnet+1].set_xscale("log")
                
        
plt.savefig("figures/lcn_q.pdf", bbox_inches='tight')
plt.savefig("figures/lcn_q.png", bbox_inches='tight')
# Out:
# 1
# 2
# 4
# 1
# 2
# 4
# 1
# 2
# 4
# 1
# 2
# 4
# 1
# 2
# 4
# 1
# 2
# 4

# %%
########OLD

# %%
ns  = [4]
sss= [2]

print("L=1, q=1 ")
###### L=3 ########
#NO WHITENING
choice = "best"

#lr = .1
width = 512
seed = 0
nets =["lcn_shared"]#i

fig, axs = plt.subplots(1,2, figsize = (20,4))
s0s = [1,2,4] #,2,4,6
Ls=[1]

for (idxL,L) in enumerate(Ls):
    colors = cm.rainbow(np.linspace(0, 1, L+1))
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
    for (idxn,n) in enumerate(ns):
        col = colors[idxn]
        for (idxq,q) in enumerate([1]):
            
            
            
          
            for (idx_s0,s0) in enumerate(s0s):
                print(s0)
        
                
                
                for (idxs,s) in enumerate(sss):
        
                    if s==4 and s0>0:
                        break
                    
                    
                    m = n**(s-1)
                    for (idxnet,net) in enumerate(nets):
                        axs[0].set_title(" Net: "+net)
                        #print(n)
                        lr = choice_lr(net,s,s0,L)
        
                        accs_cnn = []
                        
                        xx = training_point(net,s,s0,L,n,m)
                        xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
                        
                        for ptrx in xx:
        
                            #print(ptrx,pmax)
                            ptr = int(ptrx) 
                            
                            
                            tmp_seed = 0
        
                            num_seeds = 0
                            for (idx_seed,seed) in enumerate(np.array([1])):
        
        
                            #print(ptr)
                                try:
                                    tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                    tmp_seed += (100-tmp[choice]["acc"])/100
                                    num_seeds +=1
                                except:
                                    #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        
                                    pass
                            if num_seeds>0:
                                accs_cnn.append(tmp_seed/num_seeds)
                        
                        axs[0].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col,label ="n=%d"%n)  
                        
                        if s0==1:
                            mar = "o"
                        elif s0==2:
                            mar = "x"
                        elif s0==4:
                            mar = "s"
                        elif s0==6:
                            mar = "v"
                        elif s0==0:
                            mar = "d"
                        axs[0].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
        
                        #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                        #plt.axvline(x=n**4,color="red")
                        #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                        axs[0].set_xlabel(r"$P$",size = 15)
                        axs[0].set_ylabel("Test error")
                        axs[0].set_xscale("log")
#axs[0].set_yscale("log")
#legend symbols s0
s01 = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
              markersize=7, label=r'$s_0=1$')
s02 = mlines.Line2D([], [], color='black', marker='x', linestyle='None',
              markersize=7, label=r'$s_0=2$')
s03 = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
              markersize=7, label=r'$s_0=4$')
s04 = mlines.Line2D([], [], color='black', marker='v', linestyle='None',
              markersize=7, label=r'$s_0=6$')
s00 = mlines.Line2D([], [], color='black', marker='d', linestyle='None',
              markersize=7, label=r'$s_0=0$')
first_legend = axs[0].legend()
ax = axs[0].add_artist(first_legend)
legend1 = axs[0].legend(handles=[s00,s01,s02,s03],loc = 'upper left')   
axs[0].add_artist(legend1)

#legend linestyles -- vs - for L
'''
s01 = mlines.Line2D([], [], color='black', marker=None, linestyle='--',
              markersize=7, label=r'$L=2$')
s02 = mlines.Line2D([], [], color='black', marker=None, linestyle='-',
              markersize=7, label=r'$L=3$')
s03 = mlines.Line2D([], [], color='black', marker=None, linestyle=':',
              markersize=7, label=r'$L=1$')
#second_legend = axs[0].legend()
#ax = axs[0].add_artist(second_legend)
legend2 = axs[0].legend(handles=[s03,s01,s02],loc = 'upper right')   
axs[0].add_artist(legend2)
#legend colors n
'''
'''
list = []
for (idxs,s) in enumerate(sss):
    nlist.append(mlines.Line2D([], [], color=colors[idxs], marker=None, linestyle='-',
              markersize=7, label=r'$s=%d$'%(s)))
#third_legend = axs[0].legend()
#ax = axs[0].add_artist(third_legend)
axs[0].legend(handles=nlist,loc = 'lower left')  
'''
  
###############################################################



###### L=3 ########
#NO WHITENING

nets =["lcn_shared"]#


for (idxL,L) in enumerate(Ls):
    colors = cm.rainbow(np.linspace(0, 1, L+1))
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
    for (idxn,n) in enumerate(ns):
        col = colors[idxn]
        for (idxq,q) in enumerate([1]):
            
            for (idx_s0,s0) in enumerate(s0s):
                print(s0)
        
                
                for (idxs,s) in enumerate(sss):
    
                    m = n**(s-1)
                    for (idxnet,net) in enumerate(nets):
                        axs[0].set_title(" Net: "+net)
                        #print(n)
                        lr = choice_lr(net,s,s0,L)
        
                        accs_cnn = []
                        
                        #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
        
        
                        xx = training_point(net,s,s0,L,n,m)
                        xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
    
                        for ptrx in xx:
        
                            #print(ptrx,pmax)
                            ptr = int(ptrx) 
                            
                            
                            tmp_seed = 0
        
                            num_seeds = 0
                            for (idx_seed,seed) in enumerate(np.array([1])):
        
        
                            #print(ptr)
                                try:
                                    tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                    tmp_seed += (100-tmp[choice]["acc"])/100
                                    num_seeds +=1
                                except:
                                    #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        
                                    pass
                            if num_seeds>0:
                                accs_cnn.append(tmp_seed/num_seeds)
                         
                        if idxnet==0:
        
                            fac_m = n*m**(L)
                            xx = xx/(fac_m)
        
                            axs[idxnet+1].set_xlabel(r"$P/P^{*}_{0}$",size = 15)
                        elif idxnet==1:
                            fac_m = n*m**(L)
                            xx = xx/(fac_m*(s0+1)**(L))
        
                            axs[idxnet+1].set_xlabel(r"$P/(s_0+1)^L$",size = 15)
                        elif idxnet==2:
                            fac_m = n*m**(L)
                            
                            xx = xx/(fac_m*(s0+1)**(L-1+s))
        
                            axs[idxnet+1].set_xlabel(r"$P/[(s_0+1)^{L-1}(s_0+1)^s]$",size = 15)
        
                        axs[idxnet+1].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                        
                        if s0==1:
                            mar = "o"
                        elif s0==2:
                            mar = "x"
                        elif s0==4:
                            mar = "s"
                        elif s0==6:
                            mar = "v"
                        elif s0==0:
                            mar = "d"
                        axs[idxnet+1].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
        
                        #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                        #plt.axvline(x=n**4,color="red")
                        #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                        
                        axs[idxnet+1].set_xscale("log")
                    
        
#plt.savefig("diffeo_lcn_L2_A.pdf")
#plt.savefig("diffeo_lcn_L2_A.png", bbox_inches='tight')
# Out:
# L=1, q=1
# 1
# 2
# 4
# 1
# 2
# 4

# %%
ns  = [4,6,8,10]
sss= [2]
colors = cm.rainbow(np.linspace(0, 1, len(ns)))
#print("TEST IF LIKE CNN WITH s0=0 FOR q=2 ")
###### L=3 ########
#NO WHITENING
choice = "best"

#lr = .1
width = 512
seed = 0
nets =["lcn_shared"]#i

fig, axs = plt.subplots(1,2, figsize = (20,4))
s0s = [1,2,4] #,2,4,6
Ls=[2,3]

for (idxL,L) in enumerate(Ls):
    
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
    for (idxn,n) in enumerate(ns):
        col = colors[idxn]
        for (idxq,q) in enumerate(np.arange(L+1)):
            
            
            
            
        
            for (idx_s0,s0) in enumerate(s0s):
                print(s0)
        
                
                
                for (idxs,s) in enumerate(sss):
        
                    if s==4 and s0>0:
                        break
                    
                    
                    m = n**(s-1)
                    for (idxnet,net) in enumerate(nets):
                        axs[0].set_title(" Net: "+net)
                        #print(n)
                        lr = choice_lr(net,s,s0,L)
        
                        accs_cnn = []
                        
                        xx = training_point(net,s,s0,L,n,m)
                        xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
                        
                        for ptrx in xx:
        
                            #print(ptrx,pmax)
                            ptr = int(ptrx) 
                            
                            
                            tmp_seed = 0
        
                            num_seeds = 0
                            for (idx_seed,seed) in enumerate(np.array([1])):
        
        
                            #print(ptr)
                                try:
                                    tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                    tmp_seed += (100-tmp[choice]["acc"])/100
                                    num_seeds +=1
                                except:
                                    #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        
                                    pass
                            if num_seeds>0:
                                accs_cnn.append(tmp_seed/num_seeds)
                        
                        axs[0].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col,label ="n=%d"%n)  
                        
                        if s0==1:
                            mar = "o"
                        elif s0==2:
                            mar = "x"
                        elif s0==4:
                            mar = "s"
                        elif s0==6:
                            mar = "v"
                        elif s0==0:
                            mar = "d"
                        axs[0].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
        
                        #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                        #plt.axvline(x=n**4,color="red")
                        #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                        axs[0].set_xlabel(r"$P$",size = 15)
                        axs[0].set_ylabel("Test error")
                        axs[0].set_xscale("log")
#axs[0].set_yscale("log")
#legend symbols s0
s01 = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
              markersize=7, label=r'$s_0=1$')
s02 = mlines.Line2D([], [], color='black', marker='x', linestyle='None',
              markersize=7, label=r'$s_0=2$')
s03 = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
              markersize=7, label=r'$s_0=4$')
s04 = mlines.Line2D([], [], color='black', marker='v', linestyle='None',
              markersize=7, label=r'$s_0=6$')
s00 = mlines.Line2D([], [], color='black', marker='d', linestyle='None',
              markersize=7, label=r'$s_0=0$')
first_legend = axs[0].legend()
ax = axs[0].add_artist(first_legend)
legend1 = axs[0].legend(handles=[s00,s01,s02,s03],loc = 'upper left')   
axs[0].add_artist(legend1)

#legend linestyles -- vs - for L
'''
s01 = mlines.Line2D([], [], color='black', marker=None, linestyle='--',
              markersize=7, label=r'$L=2$')
s02 = mlines.Line2D([], [], color='black', marker=None, linestyle='-',
              markersize=7, label=r'$L=3$')
s03 = mlines.Line2D([], [], color='black', marker=None, linestyle=':',
              markersize=7, label=r'$L=1$')
#second_legend = axs[0].legend()
#ax = axs[0].add_artist(second_legend)
legend2 = axs[0].legend(handles=[s03,s01,s02],loc = 'upper right')   
axs[0].add_artist(legend2)
#legend colors n
'''
'''
list = []
for (idxs,s) in enumerate(sss):
    nlist.append(mlines.Line2D([], [], color=colors[idxs], marker=None, linestyle='-',
              markersize=7, label=r'$s=%d$'%(s)))
#third_legend = axs[0].legend()
#ax = axs[0].add_artist(third_legend)
axs[0].legend(handles=nlist,loc = 'lower left')  
'''
  
###############################################################



###### L=3 ########
#NO WHITENING

nets =["lcn_shared"]#


for (idxL,L) in enumerate(Ls):
 
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
    for (idxn,n) in enumerate(ns):
        col = colors[idxn]
        for (idxq,q) in enumerate(np.arange(L+1)):
            
            for (idx_s0,s0) in enumerate(s0s):
                print(s0)
        
                
                for (idxs,s) in enumerate(sss):
    
                    m = n**(s-1)
                    for (idxnet,net) in enumerate(nets):
                        axs[0].set_title(" Net: "+net)
                        #print(n)
                        lr = choice_lr(net,s,s0,L)
        
                        accs_cnn = []
                        
                        #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
        
        
                        xx = training_point(net,s,s0,L,n,m)
                        xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
    
                        for ptrx in xx:
        
                            #print(ptrx,pmax)
                            ptr = int(ptrx) 
                            
                            
                            tmp_seed = 0
        
                            num_seeds = 0
                            for (idx_seed,seed) in enumerate(np.array([1])):
        
        
                            #print(ptr)
                                try:
                                    tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                    tmp_seed += (100-tmp[choice]["acc"])/100
                                    num_seeds +=1
                                except:
                                    #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        
                                    pass
                            if num_seeds>0:
                                accs_cnn.append(tmp_seed/num_seeds)
                         
                        if idxnet==0:
        
                            fac_m = n*m**(L)
                            xx = xx/(fac_m)
        
                            axs[idxnet+1].set_xlabel(r"$P/P^{*}_{0}$",size = 15)
                        elif idxnet==1:
                            fac_m = n*m**(L)
                            if q==0:
                                xx = xx/(fac_m*(s0+1)**(L))
                            else:
        
                                axs[idxnet+1].set_xlabel(r"$P/(s_0+1)^L$",size = 15)
                        elif idxnet==2:
                            fac_m = n*m**(L)
                            
                            xx = xx/(fac_m*(s0+1)**(L-1+s))
        
                            axs[idxnet+1].set_xlabel(r"$P/[(s_0+1)^{L-1}(s_0+1)^s]$",size = 15)
        
                        axs[idxnet+1].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                        
                        if s0==1:
                            mar = "o"
                        elif s0==2:
                            mar = "x"
                        elif s0==4:
                            mar = "s"
                        elif s0==6:
                            mar = "v"
                        elif s0==0:
                            mar = "d"
                        axs[idxnet+1].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
        
                        #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                        #plt.axvline(x=n**4,color="red")
                        #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                        
                        axs[idxnet+1].set_xscale("log")
                    
        
#plt.savefig("diffeo_lcn_L2_A.pdf")
#plt.savefig("diffeo_lcn_L2_A.png", bbox_inches='tight')
# Out:
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_24_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_38_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_60_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_94_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_147_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_229_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_357_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_557_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_869_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1355_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2112_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3292_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5132_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_24_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_38_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_60_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_94_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_147_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_229_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_357_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_557_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_869_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1355_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2112_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3292_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5132_n_4_m_4_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_24_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_38_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_60_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_94_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_147_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_229_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_357_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_557_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_869_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1355_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2112_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3292_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5132_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_24_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_38_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_60_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_94_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_147_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_229_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_357_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_557_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_869_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1355_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2112_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3292_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5132_n_4_m_4_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_23_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_49_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_72_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_106_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_154_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_226_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_330_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_482_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_704_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1028_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1501_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2191_n_4_m_4_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_24_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_38_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_60_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_94_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_147_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_229_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_357_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_557_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_869_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1355_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2112_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3292_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5132_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_16_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_24_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_38_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_60_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_147_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_229_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_357_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_557_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_869_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1355_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2112_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3292_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5132_n_4_m_4_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_56_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_87_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_212_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_331_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_516_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_804_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1254_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1955_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3048_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4752_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_7408_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_11547_n_6_m_6_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_56_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_87_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_212_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_331_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_516_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_804_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1254_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1955_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3048_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4752_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_7408_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_11547_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_56_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_87_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_212_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_331_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_516_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_804_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1254_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1955_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3048_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4752_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_7408_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_11547_n_6_m_6_L_2_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_63_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_199_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_290_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_424_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_619_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_905_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1321_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1929_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2816_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4112_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6004_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_8766_n_8_m_8_L_2_q_0_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_63_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_199_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_290_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_424_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_619_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_905_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1321_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1929_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2816_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4112_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6004_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_8766_n_8_m_8_L_2_q_0_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_63_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_99_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_155_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_242_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_377_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_588_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_918_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1431_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2230_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3477_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5420_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_8448_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_13169_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20528_n_8_m_8_L_2_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_63_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_199_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_290_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_424_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_619_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_905_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1321_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1929_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2816_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4112_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6004_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_8766_n_8_m_8_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_63_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_199_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_290_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_424_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_619_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_905_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1321_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1929_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2816_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4112_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6004_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_8766_n_8_m_8_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_63_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_99_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_155_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_242_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_377_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_588_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_918_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1431_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2230_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3477_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5420_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_8448_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_13169_n_8_m_8_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# ...
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_54331_n_10_m_10_L_3_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_84690_n_10_m_10_L_3_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_132013_n_10_m_10_L_3_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_205779_n_10_m_10_L_3_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_320764_n_10_m_10_L_3_q_0_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1460_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2131_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3112_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4543_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6634_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9686_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14142_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20647_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_30146_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_44014_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_64261_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93823_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136984_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1460_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2131_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3112_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4543_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14142_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20647_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_30146_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_44014_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93823_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136984_n_10_m_10_L_3_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1460_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2131_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3112_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4543_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6634_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9686_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14142_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20647_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_30146_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_44014_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_64261_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93823_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136984_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1460_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2131_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3112_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4543_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14142_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20647_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_30146_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_44014_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136984_n_10_m_10_L_3_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1558_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2429_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3787_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5903_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9202_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14345_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_22360_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34855_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_54331_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_84690_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_132013_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_205779_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_320764_n_10_m_10_L_3_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1460_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2131_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3112_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4543_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6634_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9686_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14142_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20647_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_30146_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_44014_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_64261_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93823_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136984_n_10_m_10_L_3_q_2_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1460_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2131_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3112_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4543_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6634_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9686_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14142_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20647_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_30146_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_44014_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_64261_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93823_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136984_n_10_m_10_L_3_q_2_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1558_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2429_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3787_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5903_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9202_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14345_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_22360_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34855_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_54331_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_84690_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_132013_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_205779_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_320764_n_10_m_10_L_3_q_2_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1460_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2131_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3112_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4543_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6634_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9686_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14142_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20647_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_30146_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_44014_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_64261_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93823_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136984_n_10_m_10_L_3_q_3_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1460_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2131_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3112_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4543_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_6634_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9686_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14142_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_20647_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_30146_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_44014_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_64261_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_93823_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136984_n_10_m_10_L_3_q_3_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1000_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1558_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2429_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3787_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_5903_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_9202_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_14345_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_22360_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_34855_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_54331_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_84690_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_132013_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_205779_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_320764_n_10_m_10_L_3_q_3_s0_4_s_2_seed_1_width_512_lr_0.003.npy

# %%
v = torch.tensor([1,2,3,4,5,6,7,8])
s=2
L=2
v1 = torch.zeros(s**2)
count = 0
for k in range(s):
    for i in range(s):
        for j in range(s0+1):
            v1[count]+= v[i+j*s+k*(s*(s0+1))]
        count+=1
print(v1)
# Out:
# tensor([ 4.,  6., 12., 14.])

# %%
v = torch.tensor([1, 2, 3, 4, 5, 6, 7, 8])
s = 2
s0 = 1

# Create a grid of indices to access elements in v
k_indices = torch.arange(s).view(-1, 1, 1) * s * (s0 + 1)
i_indices = torch.arange(s).view(1, -1, 1)
j_indices = torch.arange(s0 + 1).view(1, 1, -1)

# Compute the combined indices
combined_indices = i_indices + j_indices * s + k_indices

# Sum the elements in v according to the combined indices
v1 = v[combined_indices].sum(dim=-1).view(-1)
v1
# Out:
# tensor([ 4,  6, 12, 14])

# %%
s=2
L=2
s0 =1

v = v.view(s,s*(s0+1))
v = v.sum()

# %%
ns  = [4]
sss= [2]

print("TEST IF LIKE CNN WITH s0=0 FOR q=2 for n fixed and varying L")
###### L=3 ########
#NO WHITENING
choice = "best"

#lr = .1
width = 512
seed = 0
nets =["lcn_shared"]#i

fig, axs = plt.subplots(1,2, figsize = (20,4))
s0s = [1,2,4] #,2,4,6
Ls=[2,3]
colors = cm.rainbow(np.linspace(0, 1, max(Ls)+1))

for (idxL,L) in enumerate(Ls):
    
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
    for (idxn,n) in enumerate(ns):
        col = colors[idxn]
        for (idxq,q) in enumerate([L]):
        
            for (idx_s0,s0) in enumerate(s0s):
                print(s0)
        
                
                
                for (idxs,s) in enumerate(sss):
        
                    if s==4 and s0>0:
                        break
                    
                    
                    m = n**(s-1)
                    for (idxnet,net) in enumerate(nets):
                        axs[0].set_title(" Net: "+net)
                        #print(n)
                        lr = choice_lr(net,s,s0,L)
        
                        accs_cnn = []
                        
                        xx = training_point(net,s,s0,L,n,m)
                        xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
                        
                        for ptrx in xx:
        
                            #print(ptrx,pmax)
                            ptr = int(ptrx) 
                            
                            
                            tmp_seed = 0
        
                            num_seeds = 0
                            for (idx_seed,seed) in enumerate(np.array([1])):
        
        
                            #print(ptr)
                                try:
                                    tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                    tmp_seed += (100-tmp[choice]["acc"])/100
                                    num_seeds +=1
                                except:
                                    #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        
                                    pass
                            if num_seeds>0:
                                accs_cnn.append(tmp_seed/num_seeds)
                        
                        axs[0].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col,label ="n=%d"%n)  
                        
                        if s0==1:
                            mar = "o"
                        elif s0==2:
                            mar = "x"
                        elif s0==4:
                            mar = "s"
                        elif s0==6:
                            mar = "v"
                        elif s0==0:
                            mar = "d"
                        axs[0].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
        
                        #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                        #plt.axvline(x=n**4,color="red")
                        #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                        axs[0].set_xlabel(r"$P$",size = 15)
                        axs[0].set_ylabel("Test error")
                        axs[0].set_xscale("log")
#axs[0].set_yscale("log")
#legend symbols s0
s01 = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
              markersize=7, label=r'$s_0=1$')
s02 = mlines.Line2D([], [], color='black', marker='x', linestyle='None',
              markersize=7, label=r'$s_0=2$')
s03 = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
              markersize=7, label=r'$s_0=4$')
s04 = mlines.Line2D([], [], color='black', marker='v', linestyle='None',
              markersize=7, label=r'$s_0=6$')
s00 = mlines.Line2D([], [], color='black', marker='d', linestyle='None',
              markersize=7, label=r'$s_0=0$')
first_legend = axs[0].legend()
ax = axs[0].add_artist(first_legend)
legend1 = axs[0].legend(handles=[s00,s01,s02,s03],loc = 'upper left')   
axs[0].add_artist(legend1)

#legend linestyles -- vs - for L
'''
s01 = mlines.Line2D([], [], color='black', marker=None, linestyle='--',
              markersize=7, label=r'$L=2$')
s02 = mlines.Line2D([], [], color='black', marker=None, linestyle='-',
              markersize=7, label=r'$L=3$')
s03 = mlines.Line2D([], [], color='black', marker=None, linestyle=':',
              markersize=7, label=r'$L=1$')
#second_legend = axs[0].legend()
#ax = axs[0].add_artist(second_legend)
legend2 = axs[0].legend(handles=[s03,s01,s02],loc = 'upper right')   
axs[0].add_artist(legend2)
#legend colors n
'''
'''
list = []
for (idxs,s) in enumerate(sss):
    nlist.append(mlines.Line2D([], [], color=colors[idxs], marker=None, linestyle='-',
              markersize=7, label=r'$s=%d$'%(s)))
#third_legend = axs[0].legend()
#ax = axs[0].add_artist(third_legend)
axs[0].legend(handles=nlist,loc = 'lower left')  
'''
  
###############################################################



###### L=3 ########
#NO WHITENING

nets =["lcn_shared"]#


for (idxL,L) in enumerate(Ls):
    
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
    for (idxn,n) in enumerate(ns):
        
        for (idxq,q) in enumerate([L]):
            col = colors[idxq]
            for (idx_s0,s0) in enumerate(s0s):
                print(s0)
        
                
                for (idxs,s) in enumerate(sss):
    
                    m = n**(s-1)
                    for (idxnet,net) in enumerate(nets):
                        axs[0].set_title(" Net: "+net)
                        #print(n)
                        lr = choice_lr(net,s,s0,L)
        
                        accs_cnn = []
                        
                        #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
        
        
                        xx = training_point(net,s,s0,L,n,m)
                        xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
    
                        for ptrx in xx:
        
                            #print(ptrx,pmax)
                            ptr = int(ptrx) 
                            
                            
                            tmp_seed = 0
        
                            num_seeds = 0
                            for (idx_seed,seed) in enumerate(np.array([1])):
        
        
                            #print(ptr)
                                try:
                                    tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                    tmp_seed += (100-tmp[choice]["acc"])/100
                                    num_seeds +=1
                                except:
                                    #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
        
                                    pass
                            if num_seeds>0:
                                accs_cnn.append(tmp_seed/num_seeds)
                         
                        if idxnet==0:
        
                            fac_m = n*m**(L)
                            xx = xx/(fac_m)
        
                            axs[idxnet+1].set_xlabel(r"$P/P^{*}_{0}$",size = 15)
                        elif idxnet==1:
                            fac_m = n*m**(L)
                            xx = xx/(fac_m*(s0+1)**(L))
        
                            axs[idxnet+1].set_xlabel(r"$P/(s_0+1)^L$",size = 15)
                        elif idxnet==2:
                            fac_m = n*m**(L)
                            
                            xx = xx/(fac_m*(s0+1)**(L-1+s))
        
                            axs[idxnet+1].set_xlabel(r"$P/[(s_0+1)^{L-1}(s_0+1)^s]$",size = 15)
        
                        axs[idxnet+1].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                        
                        if s0==1:
                            mar = "o"
                        elif s0==2:
                            mar = "x"
                        elif s0==4:
                            mar = "s"
                        elif s0==6:
                            mar = "v"
                        elif s0==0:
                            mar = "d"
                        axs[idxnet+1].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
        
                        #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                        #plt.axvline(x=n**4,color="red")
                        #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                        
                        axs[idxnet+1].set_xscale("log")
                    
        
#plt.savefig("diffeo_lcn_L2_A.pdf")
#plt.savefig("diffeo_lcn_L2_A.png", bbox_inches='tight')
# Out:
# TEST IF LIKE CNN WITH s0=0 FOR q=2 for n fixed and varying L
# 1
# 2
# 4
# 1
# 2
# 4
# 1
# 2
# 4
# 1
# 2
# 4

# %%
#NOT REALLY WORKING

# %%
n = 4
sss= [2]

print("TEST IF LIKE LCN FOR q=0 ")
###### L=3 ########
#NO WHITENING
choice = "best"

#lr = .1
width = 512
seed = 0
nets =["lcn_shared"]#i

fig, axs = plt.subplots(1,2, figsize = (20,4))
s0s = [1,2,4] #,2,4,6
Ls=[2]

for (idxL,L) in enumerate(Ls):
    colors = cm.rainbow(np.linspace(0, 1, L+1))
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
        
    for (idxq,q) in enumerate(range(L+1)):
        if q>0: break
        col = colors[idxq]
        
        
    
        for (idx_s0,s0) in enumerate(s0s):
            print(s0)
    
            
            
            for (idxs,s) in enumerate(sss):
    
                if s==4 and s0>0:
                    break
                
                
                m = n**(s-1)
                for (idxnet,net) in enumerate(nets):
                    axs[0].set_title(" Net: "+net)
                    #print(n)
                    lr = choice_lr(net,s,s0,L)
    
                    accs_cnn = []
                    
                    xx = training_point(net,s,s0,L,n,m)
                    xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
                    
                    for ptrx in xx:
    
                        #print(ptrx,pmax)
                        ptr = int(ptrx) 
                        
                        
                        tmp_seed = 0
    
                        num_seeds = 0
                        for (idx_seed,seed) in enumerate(np.array([1])):
    
    
                        #print(ptr)
                            try:
                                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                tmp_seed += (100-tmp[choice]["acc"])/100
                                num_seeds +=1
                            except:
                                #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    
                                pass
                        if num_seeds>0:
                            accs_cnn.append(tmp_seed/num_seeds)
                    
                    axs[0].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col,label ="q=%d"%q)  
                    
                    if s0==1:
                        mar = "o"
                    elif s0==2:
                        mar = "x"
                    elif s0==4:
                        mar = "s"
                    elif s0==6:
                        mar = "v"
                    elif s0==0:
                        mar = "d"
                    axs[0].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
    
                    #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                    #plt.axvline(x=n**4,color="red")
                    #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                    axs[0].set_xlabel(r"$P$",size = 15)
                    axs[0].set_ylabel("Test error")
                    axs[0].set_xscale("log")
#axs[0].set_yscale("log")
#legend symbols s0
s01 = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
              markersize=7, label=r'$s_0=1$')
s02 = mlines.Line2D([], [], color='black', marker='x', linestyle='None',
              markersize=7, label=r'$s_0=2$')
s03 = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
              markersize=7, label=r'$s_0=4$')
s04 = mlines.Line2D([], [], color='black', marker='v', linestyle='None',
              markersize=7, label=r'$s_0=6$')
s00 = mlines.Line2D([], [], color='black', marker='d', linestyle='None',
              markersize=7, label=r'$s_0=0$')
first_legend = axs[0].legend()
ax = axs[0].add_artist(first_legend)
legend1 = axs[0].legend(handles=[s00,s01,s02,s03],loc = 'upper left')   
axs[0].add_artist(legend1)

#legend linestyles -- vs - for L
'''
s01 = mlines.Line2D([], [], color='black', marker=None, linestyle='--',
              markersize=7, label=r'$L=2$')
s02 = mlines.Line2D([], [], color='black', marker=None, linestyle='-',
              markersize=7, label=r'$L=3$')
s03 = mlines.Line2D([], [], color='black', marker=None, linestyle=':',
              markersize=7, label=r'$L=1$')
#second_legend = axs[0].legend()
#ax = axs[0].add_artist(second_legend)
legend2 = axs[0].legend(handles=[s03,s01,s02],loc = 'upper right')   
axs[0].add_artist(legend2)
#legend colors n
'''
'''
list = []
for (idxs,s) in enumerate(sss):
    nlist.append(mlines.Line2D([], [], color=colors[idxs], marker=None, linestyle='-',
              markersize=7, label=r'$s=%d$'%(s)))
#third_legend = axs[0].legend()
#ax = axs[0].add_artist(third_legend)
axs[0].legend(handles=nlist,loc = 'lower left')  
'''
  
###############################################################



###### L=3 ########
#NO WHITENING

nets =["lcn_shared"]#


for (idxL,L) in enumerate(Ls):
    colors = cm.rainbow(np.linspace(0, 1, L+1))
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
        
    for (idxq,q) in enumerate(range(L+1)):
        if q>0: break
        col = colors[idxq]
        for (idx_s0,s0) in enumerate(s0s):
            print(s0)
    
            
            for (idxs,s) in enumerate(sss):

                m = n**(s-1)
                for (idxnet,net) in enumerate(nets):
                    axs[0].set_title(" Net: "+net)
                    #print(n)
                    lr = choice_lr(net,s,s0,L)
    
                    accs_cnn = []
                    
                    #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
    
    
                    xx = training_point(net,s,s0,L,n,m)
                    xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)

                    for ptrx in xx:
    
                        #print(ptrx,pmax)
                        ptr = int(ptrx) 
                        
                        
                        tmp_seed = 0
    
                        num_seeds = 0
                        for (idx_seed,seed) in enumerate(np.array([1])):
    
    
                        #print(ptr)
                            try:
                                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                tmp_seed += (100-tmp[choice]["acc"])/100
                                num_seeds +=1
                            except:
                                #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    
                                pass
                        if num_seeds>0:
                            accs_cnn.append(tmp_seed/num_seeds)
                     
                    if idxnet==0:
    
                        fac_m = n*m**(L)
                        xx = xx/(fac_m*(s0+1)**(L))
    
                        axs[idxnet+1].set_xlabel(r"$P/\left(P^{*}_{0}(s_0+1)^{L}\right)$",size = 15)
                    elif idxnet==1:
                        fac_m = n*m**(L)
                        xx = xx/(fac_m*(s0+1)**(L))
    
                        axs[idxnet+1].set_xlabel(r"$P/(s_0+1)^L$",size = 15)
                    elif idxnet==2:
                        fac_m = n*m**(L)
                        
                        xx = xx/(fac_m*(s0+1)**(L-1+s))
    
                        axs[idxnet+1].set_xlabel(r"$P/[(s_0+1)^{L-1}(s_0+1)^s]$",size = 15)
    
                    axs[idxnet+1].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                    
                    if s0==1:
                        mar = "o"
                    elif s0==2:
                        mar = "x"
                    elif s0==4:
                        mar = "s"
                    elif s0==6:
                        mar = "v"
                    elif s0==0:
                        mar = "d"
                    axs[idxnet+1].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
    
                    #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                    #plt.axvline(x=n**4,color="red")
                    #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                    
                    axs[idxnet+1].set_xscale("log")
                
        
#plt.savefig("diffeo_lcn_L2_A.pdf")
#plt.savefig("diffeo_lcn_L2_A.png", bbox_inches='tight')
# Out:
# TEST IF LIKE LCN FOR q=0
# 1
# 2
# 4
# 1
# 2
# 4

# %%
n = 6
sss= [2]


###### L=3 ########
#NO WHITENING
choice = "best"

#lr = .1
width = 512
seed = 0
nets =["lcn_shared"]#i



fig, axs = plt.subplots(1,3, figsize = (20,4))
s0s = [1,2,4] #,2,4,6
Ls=[2]
colors = cm.rainbow(np.linspace(0, 1, max(Ls)+1))

for (idxL,L) in enumerate(Ls):
    
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
        
    for (idxq,q) in enumerate([1]): #(range(L+1)):
        col = colors[idxq]
    
        for (idx_s0,s0) in enumerate(s0s):
            print(s0)
    
            
            
            for (idxs,s) in enumerate(sss):
    
                #if s==4 and s0>0:
                #    break
                
                
                m = n**(s-1)
                for (idxnet,net) in enumerate(nets):
                    axs[0].set_title(" Net: "+net)
                    #print(n)
                    lr = choice_lr(net,s,s0,L)
    
                    accs_cnn = []
                    
                    xx = training_point(net,s,s0,L,n,m)
                    xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
                    
                    for ptrx in xx:
    
                        #print(ptrx,pmax)
                        ptr = int(ptrx) 
                        
                        
                        tmp_seed = 0
    
                        num_seeds = 0
                        for (idx_seed,seed) in enumerate(np.array([1])):
    
    
                        #print(ptr)
                            try:
                                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                tmp_seed += (100-tmp[choice]["acc"])/100
                                num_seeds +=1
                            except:
                                #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    
                                pass
                        if num_seeds>0:
                            accs_cnn.append(tmp_seed/num_seeds)
                    
                    axs[0].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                    
                    if s0==1:
                        mar = "o"
                    elif s0==2:
                        mar = "x"
                    elif s0==4:
                        mar = "s"
                    elif s0==6:
                        mar = "v"
                    elif s0==0:
                        mar = "d"
                    axs[0].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
    
                    #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                    #plt.axvline(x=n**4,color="red")
                    #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                    axs[0].set_xlabel(r"$P$",size = 15)
                    axs[0].set_ylabel("Test error")
                    axs[0].set_xscale("log")
#axs[0].set_yscale("log")
#legend symbols s0
s01 = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
              markersize=7, label=r'$s_0=1$')
s02 = mlines.Line2D([], [], color='black', marker='x', linestyle='None',
              markersize=7, label=r'$s_0=2$')
s03 = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
              markersize=7, label=r'$s_0=4$')
s04 = mlines.Line2D([], [], color='black', marker='v', linestyle='None',
              markersize=7, label=r'$s_0=6$')
s00 = mlines.Line2D([], [], color='black', marker='d', linestyle='None',
              markersize=7, label=r'$s_0=0$')
first_legend = axs[0].legend()
ax = axs[0].add_artist(first_legend)
legend1 = axs[0].legend(handles=[s00,s01,s02,s03],loc = 'upper left')   
axs[0].add_artist(legend1)

#legend linestyles -- vs - for L

s01 = mlines.Line2D([], [], color='black', marker=None, linestyle='--',
              markersize=7, label=r'$L=2$')
s02 = mlines.Line2D([], [], color='black', marker=None, linestyle='-',
              markersize=7, label=r'$L=3$')
s03 = mlines.Line2D([], [], color='black', marker=None, linestyle=':',
              markersize=7, label=r'$L=1$')
#second_legend = axs[0].legend()
#ax = axs[0].add_artist(second_legend)
legend2 = axs[0].legend(handles=[s01,s02],loc = 'upper right')   
axs[0].add_artist(legend2)
#legend colors n

list = []
for (idxq,q) in enumerate(range(max(Ls)+1)):
    list.append(mlines.Line2D([], [], color=colors[idxq], marker=None, linestyle='-',
              markersize=7, label=r'$q=%d$'%(q)))
#third_legend = axs[0].legend()
#ax = axs[0].add_artist(third_legend)
axs[0].legend(handles=list,loc = 'lower left')  

  
###############################################################



###### L=3 ########
#NO WHITENING

nets =["lcn_shared","lcn_shared"]#


for (idxL,L) in enumerate(Ls):
    
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
        
    for (idxq,q) in enumerate([1]): #(range(L+1)):
        col = colors[idxq]
        for (idx_s0,s0) in enumerate(s0s):
            print(s0)
    
            
            for (idxs,s) in enumerate(sss):

                m = n**(s-1)
                for (idxnet,net) in enumerate(nets):
                    axs[0].set_title(" Net: "+net)
                    #print(n)
                    lr = choice_lr(net,s,s0,L)
    
                    accs_cnn = []
                    
                    #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
    
    
                    xx = training_point(net,s,s0,L,n,m)
                    xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)

                    for ptrx in xx:
    
                        #print(ptrx,pmax)
                        ptr = int(ptrx) 
                        
                        
                        tmp_seed = 0
    
                        num_seeds = 0
                        for (idx_seed,seed) in enumerate(np.array([1])):
    
    
                        #print(ptr)
                            try:
                                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                tmp_seed += (100-tmp[choice]["acc"])/100
                                num_seeds +=1
                            except:
                                #print("lcn_s_L2/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_n_"+str(n)+"_L_"+str(L)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    
                                pass
                        if num_seeds>0:
                            accs_cnn.append(tmp_seed/num_seeds)
                     
                    if idxnet==0:
    
                        fac_m = n*m**(L)
                        xx = xx/(fac_m*(s0+1)**(L-q))
    
                        axs[idxnet+1].set_xlabel(r"$P/\left(P^{*}_{0}(s_0+1)^{L-q}\right)$",size = 15)
                    elif idxnet==1:
                        fac_m = n*m**(L)
                        xx = xx/(fac_m*(s0+1)**(L-1))
    
                        axs[idxnet+1].set_xlabel(r"$P/(s_0+1)^L$",size = 15)
                    elif idxnet==2:
                        fac_m = n*m**(L)
                        
                        xx = xx/(fac_m*(s0+1)**(L-1+s))
    
                        axs[idxnet+1].set_xlabel(r"$P/[(s_0+1)^{L-1}(s_0+1)^s]$",size = 15)
    
                    axs[idxnet+1].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                    
                    if s0==1:
                        mar = "o"
                    elif s0==2:
                        mar = "x"
                    elif s0==4:
                        mar = "s"
                    elif s0==6:
                        mar = "v"
                    elif s0==0:
                        mar = "d"
                    axs[idxnet+1].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
    
                    #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                    #plt.axvline(x=n**4,color="red")
                    #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                    
                    axs[idxnet+1].set_xscale("log")
                
        
#plt.savefig("diffeo_lcn_L2_A.pdf")
#plt.savefig("diffeo_lcn_L2_A.png", bbox_inches='tight')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_56_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_87_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_212_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_331_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_516_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_804_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1254_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1955_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3048_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4752_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_7408_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_11547_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# 1
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_1_s0_1_s_2_seed_1_width_512_lr_0.01.npy
# 2
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_52_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_76_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_112_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_163_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_238_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_348_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_509_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_743_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1085_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1584_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_2313_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3377_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4931_n_6_m_6_L_2_q_1_s0_2_s_2_seed_1_width_512_lr_0.01.npy
# 4
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_56_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_87_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_212_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_331_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_516_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_804_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1254_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1955_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3048_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4752_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_7408_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_11547_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_36_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_56_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_87_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_136_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_212_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_331_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_516_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_804_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1254_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_1955_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_3048_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_4752_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_7408_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# lcn_shared/hier1_w_0_lcn_shared_diffeo_ptr_11547_n_6_m_6_L_2_q_1_s0_4_s_2_seed_1_width_512_lr_0.003.npy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/venvs/venv-for-demo/lib/python3.10/site-packages/IPython/core/formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~/venvs/venv-for-demo/lib/python3.10/site-packages/IPython/core/pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/backend_bases.py:2295, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2289     renderer = _get_renderer(
#    2290         self.figure,
#    2291         functools.partial(
#    2292             print_method, orientation=orientation)
#    2293     )
#    2294     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295         self.figure.draw(renderer)
#    2297 if bbox_inches:
#    2298     if bbox_inches == "tight":
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/figure.py:2837, in Figure.draw(self, renderer)
#    2834         # ValueError can occur when resizing a window.
#    2836 self.patch.draw(renderer)
# -> 2837 mimage._draw_list_compositing_images(
#    2838     renderer, self, artists, self.suppressComposite)
#    2840 for sfig in self.subfigs:
#    2841     sfig.draw(renderer)
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/axes/_base.py:3091, in _AxesBase.draw(self, renderer)
#    3088         a.draw(renderer)
#    3089     renderer.stop_rasterizing()
# -> 3091 mimage._draw_list_compositing_images(
#    3092     renderer, self, artists, self.figure.suppressComposite)
#    3094 renderer.close_group('axes')
#    3095 self.stale = False
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/axis.py:1158, in Axis.draw(self, renderer, *args, **kwargs)
#    1155     return
#    1156 renderer.open_group(__name__, gid=self.get_gid())
# -> 1158 ticks_to_draw = self._update_ticks()
#    1159 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                         renderer)
#    1162 for tick in ticks_to_draw:
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/axis.py:1045, in Axis._update_ticks(self)
#    1040 def _update_ticks(self):
#    1041     """
#    1042     Update ticks (position and labels) using the current data interval of
#    1043     the axes.  Return the list of ticks that will be drawn.
#    1044     """
# -> 1045     major_locs = self.get_majorticklocs()
#    1046     major_labels = self.major.formatter.format_ticks(major_locs)
#    1047     major_ticks = self.get_major_ticks(len(major_locs))
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/axis.py:1277, in Axis.get_majorticklocs(self)
#    1275 def get_majorticklocs(self):
#    1276     """Return this Axis' major tick locations in data coordinates."""
# -> 1277     return self.major.locator()
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/ticker.py:2293, in LogLocator.__call__(self)
#    2291 """Return the locations of the ticks."""
#    2292 vmin, vmax = self.axis.get_view_interval()
# -> 2293 return self.tick_values(vmin, vmax)
#
# File /ssoft/spack/syrah/v1/opt/spack/linux-rhel8-skylake_avx512/gcc-11.3.0/python-3.10.4-aeswhfwtqxxw6iwadndinzfqccarjg3r/lib/python3.10/site-packages/matplotlib/ticker.py:2318, in LogLocator.tick_values(self, vmin, vmax)
#    2315         vmin = self.axis.get_minpos()
#    2317     if vmin <= 0.0 or not np.isfinite(vmin):
# -> 2318         raise ValueError(
#    2319             "Data has no positive values, and therefore can not be "
#    2320             "log-scaled.")
#    2322 _log.debug('vmin %s vmax %s', vmin, vmax)
#    2324 if vmax < vmin:
#
# ValueError: Data has no positive values, and therefore can not be log-scaled.

# %%
#missing L=3, s0=4,q>0

# %%
n = 4
sss= [2]


###### L=3 ########
#NO WHITENING
choice = "best"

#lr = .1
width = 512
seed = 0
nets =["lcn_shared"]#i



fig, axs = plt.subplots(1,2, figsize = (20,4))
s0s = [4] #,2,4,6
Ls=[3]
colors = cm.rainbow(np.linspace(0, 1, max(Ls)+1))

for (idxL,L) in enumerate(Ls):
    
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
        
    for (idxq,q) in enumerate(range(L+1)):
        col = colors[idxq]
        print('q')
        print(q)
    
        for (idx_s0,s0) in enumerate(s0s):
            print(s0)
    
            
            
            for (idxs,s) in enumerate(sss):
    

                
                
                m = n**(s-1)
                for (idxnet,net) in enumerate(nets):
                    axs[0].set_title(" Net: "+net)
                    #print(n)
                    lr = choice_lr(net,s,s0,L)
    
                    accs_cnn = []
                    
                    xx = training_point(net,s,s0,L,n,m)
                    xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)
                    
                    for ptrx in xx:
    
                        #print(ptrx,pmax)
                        ptr = int(ptrx) 
                        
                        
                        tmp_seed = 0
    
                        num_seeds = 0
                        for (idx_seed,seed) in enumerate(np.array([1])):
    
    
                        #print(ptr)
                            try:
                                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                tmp_seed += (100-tmp[choice]["acc"])/100
                                num_seeds +=1
                            except:
                                print("lcn_shared/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_q_"+str(q)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    
                                pass
                        if num_seeds>0:
                            accs_cnn.append(tmp_seed/num_seeds)
                    
                    axs[0].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                    
                    if s0==1:
                        mar = "o"
                    elif s0==2:
                        mar = "x"
                    elif s0==4:
                        mar = "s"
                    elif s0==6:
                        mar = "v"
                    elif s0==0:
                        mar = "d"
                    axs[0].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
    
                    #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                    #plt.axvline(x=n**4,color="red")
                    #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                    axs[0].set_xlabel(r"$P$",size = 15)
                    axs[0].set_ylabel("Test error")
                    axs[0].set_xscale("log")
#axs[0].set_yscale("log")
#legend symbols s0
s01 = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
              markersize=7, label=r'$s_0=1$')
s02 = mlines.Line2D([], [], color='black', marker='x', linestyle='None',
              markersize=7, label=r'$s_0=2$')
s03 = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
              markersize=7, label=r'$s_0=4$')
s04 = mlines.Line2D([], [], color='black', marker='v', linestyle='None',
              markersize=7, label=r'$s_0=6$')
s00 = mlines.Line2D([], [], color='black', marker='d', linestyle='None',
              markersize=7, label=r'$s_0=0$')
first_legend = axs[0].legend()
ax = axs[0].add_artist(first_legend)
legend1 = axs[0].legend(handles=[s00,s01,s02,s03],loc = 'upper left')   
axs[0].add_artist(legend1)

#legend linestyles -- vs - for L

s01 = mlines.Line2D([], [], color='black', marker=None, linestyle='--',
              markersize=7, label=r'$L=2$')
s02 = mlines.Line2D([], [], color='black', marker=None, linestyle='-',
              markersize=7, label=r'$L=3$')
s03 = mlines.Line2D([], [], color='black', marker=None, linestyle=':',
              markersize=7, label=r'$L=1$')
#second_legend = axs[0].legend()
#ax = axs[0].add_artist(second_legend)
legend2 = axs[0].legend(handles=[s01,s02],loc = 'upper right')   
axs[0].add_artist(legend2)
#legend colors n

list = []
for (idxq,q) in enumerate(range(max(Ls)+1)):
    list.append(mlines.Line2D([], [], color=colors[idxq], marker=None, linestyle='-',
              markersize=7, label=r'$q=%d$'%(q)))
#third_legend = axs[0].legend()
#ax = axs[0].add_artist(third_legend)
axs[0].legend(handles=list,loc = 'lower left')  

  
###############################################################



###### L=3 ########
#NO WHITENING

nets =["lcn_shared"]#


for (idxL,L) in enumerate(Ls):
    
    if L==2: lss = '--'
    elif L==3: lss = '-'
    elif L==1: lss = ':'
        
    for (idxq,q) in enumerate(range(L+1)):
        col = colors[idxq]
        for (idx_s0,s0) in enumerate(s0s):
            print(s0)
    
            
            for (idxs,s) in enumerate(sss):

                m = n**(s-1)
                for (idxnet,net) in enumerate(nets):
                    axs[0].set_title(" Net: "+net)
                    #print(n)
                    lr = choice_lr(net,s,s0,L)
    
                    accs_cnn = []
                    
                    #pmax = ((2*s0+2)**(2**L -1))*n**(2**L)
    
    
                    xx = training_point(net,s,s0,L,n,m)
                    xx = training_point_new(xx,net,n,m,L,q,s0,s,width,lr)

                    for ptrx in xx:
    
                        #print(ptrx,pmax)
                        ptr = int(ptrx) 
                        
                        
                        tmp_seed = 0
    
                        num_seeds = 0
                        for (idx_seed,seed) in enumerate(np.array([1])):
    
    
                        #print(ptr)
                            try:
                                tmp = load_net(net,ptr,n,m,L,q,s0,s,seed,width,lr)
                                tmp_seed += (100-tmp[choice]["acc"])/100
                                num_seeds +=1
                            except:
                                print("lcn_shared/hier1_w_0_"+net+"_diffeo_ptr_"+str(ptr)+"_n_"+str(n)+"_m_"+str(m)+"_L_"+str(L)+"_q_"+str(q)+"_s0_"+str(s0)+"_s_"+str(s)+"_seed_"+str(seed)+"_width_"+str(width)+"_lr_"+str(lr)+".npy")
    
                                pass
                        if num_seeds>0:
                            accs_cnn.append(tmp_seed/num_seeds)
                     
                    if idxnet==0:
    
                        fac_m = n*m**(L)
                        xx = xx/(fac_m*(s0+1)**(L-q))
    
                        axs[idxnet+1].set_xlabel(r"$P/\left(P^{*}_{0}(s_0+1)^{L-q}\right)$",size = 15)
                    elif idxnet==1:
                        fac_m = n*m**(L)
                        xx = xx/(fac_m*(s0+1)**(L))
    
                        axs[idxnet+1].set_xlabel(r"$P/(s_0+1)^L$",size = 15)
                    elif idxnet==2:
                        fac_m = n*m**(L)
                        
                        xx = xx/(fac_m*(s0+1)**(L-1+s))
    
                        axs[idxnet+1].set_xlabel(r"$P/[(s_0+1)^{L-1}(s_0+1)^s]$",size = 15)
    
                    axs[idxnet+1].plot(xx[:len(accs_cnn)]*n,accs_cnn,ls=lss,color = col)  
                    
                    if s0==1:
                        mar = "o"
                    elif s0==2:
                        mar = "x"
                    elif s0==4:
                        mar = "s"
                    elif s0==6:
                        mar = "v"
                    elif s0==0:
                        mar = "d"
                    axs[idxnet+1].scatter(xx[:len(accs_cnn)]*n,accs_cnn,marker = mar,color = col) 
    
                    #plt.plot(xx[:len(accs_fcn_L)],accs_fcn_L,label="FCN",ls="-") 
                    #plt.axvline(x=n**4,color="red")
                    #plt.plot(red_xx,np.ones(len(red_xx))*(1/n)*100,label="chance 1/n",ls="--",color="black")  
                    
                    axs[idxnet+1].set_xscale("log")
                
        
#plt.savefig("diffeo_lcn_L2_A.pdf")
#plt.savefig("diffeo_lcn_L2_A.png", bbox_inches='tight')
# Out:
# q
# 0
# 4
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# q
# 1
# 4
# q
# 2
# 4
# q
# 3
# 4
# 4
# 4
# 4
# 4
